# %% [markdown]
# <a href="https://colab.research.google.com/github/anushkagupta19/Agentic-AI-Health-Symptom-Checker/blob/main/Data_Prep_Kit_Demo_Cleaned_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 📄 Data Prep Toolkit Demo (Cleaned Version)
# This notebook demonstrates how to use the Data Prep Toolkit (DPK) to convert PDFs and ZIP files to Parquet format.
# All required steps are fixed and executable in a standard Jupyter/Colab environment.

# %%
# ✅ Install required libraries
# !pip install "data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2" pandas pyarrow
# Out:
# ERROR: Ignored the following versions that require a different python version: 0.2.1 Requires-Python <3.12,>=3.10; 0.2.1.dev0 Requires-Python <3.12,>=3.10; 0.2.1.dev1 Requires-Python <3.12,>=3.10; 0.2.1.dev2 Requires-Python <3.12,>=3.10; 0.2.1.dev3 Requires-Python <3.12,>=3.10; 0.2.2 Requires-Python <3.13,>=3.10; 0.2.2.dev1 Requires-Python <3.13,>=3.10; 0.2.2.dev2 Requires-Python <3.13,>=3.10; 0.2.2.dev3 Requires-Python <3.13,>=3.10; 0.2.3 Requires-Python <3.13,>=3.10; 0.2.3.dev0 Requires-Python <3.13,>=3.10; 0.2.3.dev1 Requires-Python <3.13,>=3.10; 0.2.3.dev2 Requires-Python <3.13,>=3.10; 1.0.0 Requires-Python <3.13,>=3.10; 1.0.0a0 Requires-Python <3.13,>=3.10; 1.0.0a1 Requires-Python <3.13,>=3.10; 1.0.0a2 Requires-Python <3.13,>=3.10; 1.0.0a3 Requires-Python <3.13,>=3.10; 1.0.0a4 Requires-Python <3.13,>=3.10; 1.0.0a5 Requires-Python <3.13,>=3.10; 1.0.1.dev0 Requires-Python <3.13,>=3.10; 1.0.1.dev1 Requires-Python <3.13,>=3.10; 1.0.1.dev2 Requires-Python <3.13,>=3.10; 1.0.1.dev3 Req
# ...

# %%
# ✅ Import modules
import os
import urllib.request
from dpk_pdf2parquet.transform_python import Pdf2Parquet
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 4
#       2 import os
#       3 import urllib.request
# ----> 4 from dpk_pdf2parquet.transform_python import Pdf2Parquet
#
# ModuleNotFoundError: No module named 'dpk_pdf2parquet'

# %%
# ✅ Create input directory and download sample data
os.makedirs("tmp/input", exist_ok=True)
urllib.request.urlretrieve(
    "https://raw.githubusercontent.com/data-prep-kit/data-prep-kit/dev/transforms/language/docling2parquet/test-data/input/archive1.zip",
    "tmp/input/archive1.zip"
)
urllib.request.urlretrieve(
    "https://raw.githubusercontent.com/data-prep-kit/data-prep-kit/dev/transforms/language/docling2parquet/test-data/input/redp5110-ch1.pdf",
    "tmp/input/redp5110-ch1.pdf"
)
# Out:
# ('tmp/input/redp5110-ch1.pdf', <http.client.HTTPMessage at 0x7e429d2f40d0>)

# %%
# ✅ Run PDF2Parquet Transformation
Pdf2Parquet(
    input_folder="tmp/input",
    output_folder="tmp/output",
    data_files_to_use=[".pdf", ".zip"]
).transform()
# Out:
# 17:46:19 INFO - pdf2parquet parameters are : {'batch_size': -1, 'artifacts_path': None, 'contents_type': <pdf2parquet_contents_types.MARKDOWN: 'text/markdown'>, 'do_table_structure': True, 'do_ocr': True, 'ocr_engine': <pdf2parquet_ocr_engine.EASYOCR: 'easyocr'>, 'bitmap_area_threshold': 0.05, 'pdf_backend': <pdf2parquet_pdf_backend.DLPARSE_V2: 'dlparse_v2'>, 'double_precision': 8}
# INFO:dpk_pdf2parquet.transform:pdf2parquet parameters are : {'batch_size': -1, 'artifacts_path': None, 'contents_type': <pdf2parquet_contents_types.MARKDOWN: 'text/markdown'>, 'do_table_structure': True, 'do_ocr': True, 'ocr_engine': <pdf2parquet_ocr_engine.EASYOCR: 'easyocr'>, 'bitmap_area_threshold': 0.05, 'pdf_backend': <pdf2parquet_pdf_backend.DLPARSE_V2: 'dlparse_v2'>, 'double_precision': 8}
# 17:46:19 INFO - pipeline id pipeline_id
# INFO:data_processing.runtime.execution_configuration:pipeline id pipeline_id
# ...

# %%
# ✅ Load the converted Parquet files
import pyarrow.parquet as pq
import pandas as pd

archive_table = pq.read_table('tmp/output/archive1.parquet')
archive_df = archive_table.to_pandas()
archive_df.head()
# Out:
#                filename                                           contents  \
# 0  2305.03393v1-pg9.pdf  order to compute the TED score. Inference timi...
# 1  2408.09869v1-pg1.pdf  <!-- image -->\n\n## Docling TechnicalReport\n...
#
#    num_pages  num_tables  num_doc_elements  \
# 0          1           1                 9
# 1          1           0                12
#
#                             document_id        document_hash  ext  \
# 0  2f8e2f49-37b3-472b-b16f-c9fcf4e432e9  3463920545297462180  pdf
# 1  5c84dff4-c5aa-4176-9b74-9411db4af167   582377908831471240  pdf
#
#                                                 hash  size  \
# 0  f7a3dbb9737d54765bbc85896c98960449e9e93b12c07a...  2908
# 1  b5947c1090eaa3140562f4acfc85aa2d6ad01e7f14e255...  2040
#
#                 date_acquired  pdf_convert_time source_filename
# 0  2025-08-04T17:47:11.348918          9.907809    archive1.zip
# 1  2025-08-04T17:47:15.080027          3.727122    archive1.zip

# %%
# ✅ Load second converted file
pdf_table = pq.read_table('tmp/output/redp5110-ch1.parquet')
pdf_df = pdf_table.to_pandas()
pdf_df.head()
# Out:
#            filename                                           contents  \
# 0  redp5110-ch1.pdf  <!-- image -->\n\nChapter 1.\n\n1\n\n## Securi...
#
#    num_pages  num_tables  num_doc_elements  \
# 0          5           0                48
#
#                             document_id      document_hash  ext  \
# 0  ae4e09ca-31dd-46b6-bf3a-87f35f1745c6  74198560999363607  pdf
#
#                                                 hash  size  \
# 0  34ffc0b779b80e74f0cdab4f0869ab623ccb66aad0773c...  9581
#
#                 date_acquired  pdf_convert_time   source_filename
# 0  2025-08-04T17:48:03.122329         47.983531  redp5110-ch1.pdf
